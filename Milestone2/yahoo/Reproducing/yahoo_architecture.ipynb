# %% [markdown]
# # IMPORTS

# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import lr_scheduler
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torchvision
from torchvision import datasets,models,transforms
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import math
import os
import copy
import time
import sqlite3 as sql
import cv2
from tqdm import tqdm

# %% [markdown]
# # CONSTANTS DEFINITION

# %%
MLP_KERNEL_SIZE = 1
MLP_FILTERS_1 = 256
MLP_FILTERS_2 = 64
CONTRACTION_RATIO = 2
PADDING_METHOD = 'same'
UPSAMPLE_MODE = 'nearest'
N_FEATURE_EXTRACTED = 2048
N_CLASSES = 17
SEQUENCE_SIZE = 112
BATCH_SIZE = 256
BATCH_PER_EPOCH = 1000

# %% [markdown]
# # DATA LOADING

# %%
db = "/scratch/users/mdelabrassinne/Database/SoccerDB.db"
con = sql.connect(db)
cur = con.cursor()
query_result = cur.execute("SELECT Path_video FROM VIDEO WHERE Path_video LIKE '%england_epl%' OR Path_video LIKE '%france_ligue-1%' OR Path_video LIKE '%europe_uefa-champions-league%'")
training_vids = copy.deepcopy([q[0] for q in query_result.fetchall()])

# %% [markdown]
# # Extract the frames of a part of a video

# %%
def extract_frames(video_path, start_time, end_time, frame_rate ,frames):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Set the starting frame to extract
    cap.set(cv2.CAP_PROP_POS_MSEC, start_time * 1000)

    # Calculate the total number of frames to extract
    total_frames = int((end_time - start_time) * frame_rate)

    # Extract the frames
    for i in tqdm(range(total_frames)):
        # Read the next frame
        ret, frame = cap.read()
        if ret:
            # Add the frame to the list
            frames.append(frame)
        else:
            break

        # Set the position to the next frame
        cap.set(cv2.CAP_PROP_POS_FRAMES, int(cap.get(cv2.CAP_PROP_POS_FRAMES)) + int(cap.get(cv2.CAP_PROP_FPS) / frame_rate))

    # Release the video capture
    cap.release()

# test of the function:
frames = []

# %timeit extract_frames('/scratch/users/mdelabrassinne/Database/england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/1_224p.mkv',0,112,1,frames)

i = 0
for i in range(5):
    cv2.imwrite("frame{i}.png".format(i=i),frames[i])
# Out:
# 100%|██████████| 112/112 [00:07<00:00, 14.87it/s]
# 100%|██████████| 112/112 [00:07<00:00, 14.37it/s]
# 100%|██████████| 112/112 [00:07<00:00, 14.84it/s]
# 100%|██████████| 112/112 [00:07<00:00, 15.02it/s]
# 100%|██████████| 112/112 [00:07<00:00, 14.89it/s]
# 100%|██████████| 112/112 [00:07<00:00, 14.93it/s]
# 100%|██████████| 112/112 [00:07<00:00, 14.79it/s]
# 100%|██████████| 112/112 [00:07<00:00, 15.03it/s]
# 7.57 s ± 108 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
torchvision.io.read_video('/scratch/users/mdelabrassinne/Database/england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/1_224p.mkv',0,112,)

# %%
for i in range(3):
    print("frame{i}".format(i = i))
# Out:
# frame0
# frame1
# frame2

# %%
def batch_creation(batch_size,sequence_size,videos):
    
    #get the videos path we consider
    videos_chosen = np.random.choice(len(videos),256)
    
    #get the associated jsons
    jsons = [os.path.join(os.path.dirname(videos[vid]),"Labels-v2.json") for vid in videos_chosen]
    
    #zip the 2 
    result =  [(videos[vid],json) for vid,json in zip(videos_chosen,jsons)]
    starting_times = np.random.choice(45*60,256)
    images = []
    for i in tqdm(len(starting_times.shape[0])):
        X = []
        extract_frames(videos[videos_chosen[i]],starting_times[i],starting_times[i]+112,1,X)
        get_actions = 
        
        
        
#test
batch_creation(BATCH_SIZE,SEQUENCE_SIZE,training_vids)
# Out:
# [('/scratch/users/mdelabrassinne/Database/france_ligue-1/2014-2015/2015-04-05_-_22-00_Marseille_2_-_3_Paris_SG/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/france_ligue-1/2014-2015/2015-04-05_-_22-00_Marseille_2_-_3_Paris_SG/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2014-2015/2015-03-18_-_22-45_Dortmund_0_-_3_Juventus/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2014-2015/2015-03-18_-_22-45_Dortmund_0_-_3_Juventus/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2015-09-26_-_17-00_Leicester_2_-_5_Arsenal/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2015-09-26_-_17-00_Leicester_2_-_5_Arsenal/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/france_ligue-1/2015-2016/2015-11-07_-_19-00_Paris_SG_5_-_0_Toulouse/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/france_ligue-1/2015-2016/2015-11-07_-_19-00_Paris_SG_5_-_0_Toulouse/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-09-15_-_21-45_Manchester_City_1_-_2_Juventus/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-09-15_-_21-45_Manchester_City_1_-_2_Juventus/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/france_ligue-1/2014-2015/2015-04-05_-_22-00_Marseille_2_-_3_Paris_SG/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/france_ligue-1/2014-2015/2015-04-05_-_22-00_Marseille_2_-_3_Paris_SG/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-03_-_22-45_Shakhtar_Donetsk_4_-_0_Malmo_FF/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-03_-_22-45_Shakhtar_Donetsk_4_-_0_Malmo_FF/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/england_epl/2016-2017/2017-05-06_-_17-00_Leicester_3_-_0_Watford/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/england_epl/2016-2017/2017-05-06_-_17-00_Leicester_3_-_0_Watford/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2016-01-13_-_22-45_Chelsea_2_-_2_West_Brom/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2016-01-13_-_22-45_Chelsea_2_-_2_West_Brom/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2016-2017/2016-11-01_-_22-45_Manchester_City_3_-_1_Barcelona/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2016-2017/2016-11-01_-_22-45_Manchester_City_3_-_1_Barcelona/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-09-15_-_21-45_Real_Madrid_4_-_0_Shakhtar_Donetsk/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-09-15_-_21-45_Real_Madrid_4_-_0_Shakhtar_Donetsk/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2016-02-13_-_20-30_Chelsea_5_-_1_Newcastle_Utd/1_224p.mkv', '/scratch/users/mdelabrassinne/Database/england_epl/2015-2016/2016-02-13_-_20-30_Chelsea_5_-_1_Newcastle_Utd/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2016-2017/2016-09-28_-_21-45_Napoli_4_-_2_Benfica/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2016-2017/2016-09-28_-_21-45_Napoli_4_-_2_Benfica/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-24_-_20-00_BATE_1_-_1_Bayer_Leverkusen/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-24_-_20-00_BATE_1_-_1_Bayer_Leverkusen/Labels-v2.json'), ('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-24_-_22-45_Maccabi_Tel_Aviv_0_-_4_Chelsea/2_224p.mkv', '/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-11-24_-_22-45_Maccabi_Tel_Aviv_0_-_4_Chelsea/L ...

# %%
import json
json.load(open('/scratch/users/mdelabrassinne/Database/europe_uefa-champions-league/2015-2016/2015-09-16_-_21-45_Chelsea_4_-_0_Maccabi_Tel_Aviv/Labels-v2.json'))
# Out:
# {'UrlLocal': 'europe_uefa-champions-league/2015-2016/2015-09-16 - 21-45 Chelsea 4 - 0 Maccabi Tel Aviv/',
#  'UrlYoutube': '',
#  'annotations': [{'gameTime': '1 - 00:00',
#    'label': 'Kick-off',
#    'position': '165',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 00:34',
#    'label': 'Ball out of play',
#    'position': '34658',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 00:41',
#    'label': 'Throw-in',
#    'position': '41913',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 00:44',
#    'label': 'Foul',
#    'position': '44097',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 00:45',
#    'label': 'Ball out of play',
#    'position': '45700',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 00:59',
#    'label': 'Yellow card',
#    'position': '59547',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 01:49',
#    'label': 'Indirect free-kick',
#    'position': '109478',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 02:40',
#    'label': 'Foul',
#    'position': '160978',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 03:06',
#    'label': 'Indirect free-kick',
#    'position': '186157',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 03:14',
#    'label': 'Foul',
#    'position': '194767',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 04:20',
#    'label': 'Foul',
#    'position': '260467',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 04:22',
#    'label': 'Ball out of play',
#    'position': '262619',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 04:33',
#    'label': 'Yellow card',
#    'position': '273886',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 05:13',
#    'label': 'Penalty',
#    'position': '313683',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 05:13',
#    'label': 'Shots off target',
#    'position': '313683',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 05:14',
#    'label': 'Ball out of play',
#    'position': '314157',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 05:48',
#    'label': 'Clearance',
#    'position': '348774',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 06:02',
#    'label': 'Foul',
#    'position': '362744',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 06:16',
#    'label': 'Indirect free-kick',
#    'position': '376015',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 06:25',
#    'label': 'Foul',
#    'position': '385510',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 06:31',
#    'label': 'Indirect free-kick',
#    'position': '391840',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 07:05',
#    'label': 'Ball out of play',
#    'position': '425995',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 07:25',
#    'label': 'Throw-in',
#    'position': '445846',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 07:32',
#    'label': 'Ball out of play',
#    'position': '452000',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 07:45',
#    'label': 'Clearance',
#    'position': '465321',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 07:55',
#    'label': 'Ball out of play',
#    'position': '475759',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 08:05',
#    'label': 'Throw-in',
#    'position': '485151',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 08:33',
#    'label': 'Ball out of play',
#    'position': '513539',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 08:44',
#    'label': 'Throw-in',
#    'position': '524782',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 09:23',
#    'label': 'Foul',
#    'position': '563235',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 09:26',
#    'label': 'Indirect free-kick',
#    'position': '566426',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 10:05',
#    'label': 'Foul',
#    'position': '605074',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 11:06',
#    'label': 'Direct free-kick',
#    'position': '666008',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 12:16',
#    'label': 'Clearance',
#    'position': '736545',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 13:06',
#    'label': 'Ball out of play',
#    'position': '786010',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 13:10',
#    'label': 'Throw-in',
#    'position': '790027',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 13:50',
#    'label': 'Foul',
#    'position': '830288',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 14:36',
#    'label': 'Direct free-kick',
#    'position': '876473',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 14:36',
#    'label': 'Shots on target',
#    'position': '876484',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 14:38',
#    'label': 'Goal',
#    'position': '878365',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 15:11',
#    'label': 'Kick-off',
#    'position': '911919',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 15:40',
#    'label': 'Ball out of play',
#    'position': '940153',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 15:54',
#    'label': 'Throw-in',
#    'position': '954164',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 15:57',
#    'label': 'Ball out of play',
#    'position': '957672',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 16:13',
#    'label': 'Clearance',
#    'position': '973810',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 17:43',
#    'label': 'Ball out of play',
#    'position': '1063515',
#    'team': 'not applicable',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 18:58',
#    'label': 'Throw-in',
#    'position': '1138067',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 19:57',
#    'label': 'Foul',
#    'position': '1197373',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 20:01',
#    'label': 'Indirect free-kick',
#    'position': '1201833',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 20:19',
#    'label': 'Ball out of play',
#    'position': '1219214',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 20:31',
#    'label': 'Throw-in',
#    'position': '1231808',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 20:34',
#    'label': 'Ball out of play',
#    'position': '1234783',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 20:41',
#    'label': 'Throw-in',
#    'position': '1241387',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 21:20',
#    'label': 'Foul',
#    'position': '1280356',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 21:33',
#    'label': 'Ball out of play',
#    'position': '1293460',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 21:40',
#    'label': 'Throw-in',
#    'position': '1300615',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 22:14',
#    'label': 'Offside',
#    'position': '1334340',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 22:58',
#    'label': 'Substitution',
#    'position': '1378000',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 23:02',
#    'label': 'Indirect free-kick',
#    'position': '1382577',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 23:19',
#    'label': 'Offside',
#    'position': '1399813',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 23:27',
#    'label': 'Indirect free-kick',
#    'position': '1407494',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 23:52',
#    'label': 'Ball out of play',
#    'position': '1432671',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 24:14',
#    'label': 'Corner',
#    'position': '1454311',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 24:15',
#    'label': 'Shots off target',
#    'position': '1455854',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 24:16',
#    'label': 'Ball out of play',
#    'position': '1456512',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 24:42',
#    'label': 'Kick-off',
#    'position': '1482037',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 24:47',
#    'label': 'Ball out of play',
#    'position': '1487900',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 25:00',
#    'label': 'Throw-in',
#    'position': '1500109',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 25:19',
#    'label': 'Foul',
#    'position': '1519268',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 25:21',
#    'label': 'Ball out of play',
#    'position': '1521148',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 25:31',
#    'label': 'Indirect free-kick',
#    'position': '1531533',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 25:57',
#    'label': 'Foul',
#    'position': '1557796',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 26:20',
#    'label': 'Indirect free-kick',
#    'position': '1580231',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 27:28',
#    'label': 'Foul',
#    'position': '1648939',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 28:04',
#    'label': 'Direct free-kick',
#    'position': '1684239',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 28:06',
#    'label': 'Ball out of play',
#    'position': '1686163',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 28:31',
#    'label': 'Clearance',
#    'position': '1711080',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 29:21',
#    'label': 'Ball out of play',
#    'position': '1761307',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 29:26',
#    'label': 'Throw-in',
#    'position': '1766971',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 29:40',
#    'label': 'Foul',
#    'position': '1780941',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 30:29',
#    'label': 'Direct free-kick',
#    'position': '1829252',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 30:30',
#    'label': 'Shots off target',
#    'position': '1830733',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 30:31',
#    'label': 'Ball out of play',
#    'position': '1831482',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 30:56',
#    'label': 'Clearance',
#    'position': '1856911',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 31:00',
#    'label': 'Ball out of play',
#    'position': '1860622',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 31:23',
#    'label': 'Throw-in',
#    'position': '1883820',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 31:39',
#    'label': 'Ball out of play',
#    'position': '1899760',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 31:54',
#    'label': 'Corner',
#    'position': '1914212',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 31:58',
#    'label': 'Shots off target',
#    'position': '1918690',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 32:00',
#    'label': 'Ball out of play',
#    'position': '1920804',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 32:24',
#    'label': 'Clearance',
#    'position': '1944269',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 32:32',
#    'label': 'Foul',
#    'position': '1952133',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 32:38',
#    'label': 'Yellow card',
#    'position': '1958000',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 32:59',
#    'label': 'Indirect free-kick',
#    'position': '1979475',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 33:13',
#    'label': 'Ball out of play',
#    'position': '1993252',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 33:16',
#    'label': 'Throw-in',
#    'position': '1996006',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 33:33',
#    'label': 'Ball out of play',
#    'position': '2013978',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 33:37',
#    'label': 'Throw-in',
#    'position': '2017167',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 34:31',
#    'label': 'Ball out of play',
#    'position': '2071572',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 34:44',
#    'label': 'Corner',
#    'position': '2084680',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 35:15',
#    'label': 'Ball out of play',
#    'position': '2115561',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 35:38',
#    'label': 'Corner',
#    'position': '2138237',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 36:32',
#    'label': 'Ball out of play',
#    'position': '2192150',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 36:44',
#    'label': 'Corner',
#    'position': '2204874',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 37:10',
#    'label': 'Shots off target',
#    'position': '2230582',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 37:11',
#    'label': 'Offside',
#    'position': '2231110',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 37:15',
#    'label': 'Ball out of play',
#    'position': '2235945',
#    'team': 'not applicable',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 37:47',
#    'label': 'Indirect free-kick',
#    'position': '2267122',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 37:57',
#    'label': 'Ball out of play',
#    'position': '2277974',
#    'team': 'not applicable',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 38:17',
#    'label': 'Throw-in',
#    'position': '2297960',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 38:39',
#    'label': 'Ball out of play',
#    'position': '2319934',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 38:57',
#    'label': 'Clearance',
#    'position': '2337476',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 39:08',
#    'label': 'Foul',
#    'position': '2348081',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 39:12',
#    'label': 'Shots off target',
#    'position': '2352298',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 39:45',
#    'label': 'Clearance',
#    'position': '2385316',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 40:33',
#    'label': 'Offside',
#    'position': '2433491',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 40:47',
#    'label': 'Indirect free-kick',
#    'position': '2447288',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 41:10',
#    'label': 'Ball out of play',
#    'position': '2470348',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 41:33',
#    'label': 'Throw-in',
#    'position': '2493553',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 41:48',
#    'label': 'Ball out of play',
#    'position': '2508442',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 41:55',
#    'label': 'Throw-in',
#    'position': '2515318',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 41:58',
#    'label': 'Ball out of play',
#    'position': '2518936',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 42:02',
#    'label': 'Throw-in',
#    'position': '2522236',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 42:42',
#    'label': 'Ball out of play',
#    'position': '2562911',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 43:02',
#    'label': 'Corner',
#    'position': '2582783',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 43:17',
#    'label': 'Foul',
#    'position': '2597635',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 44:05',
#    'label': 'Indirect free-kick',
#    'position': '2645794',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 44:09',
#    'label': 'Ball out of play',
#    'position': '2649918',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 44:19',
#    'label': 'Throw-in',
#    'position': '2659388',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 44:23',
#    'label': 'Ball out of play',
#    'position': '2663875',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 44:35',
#    'label': 'Clearance',
#    'position': '2675095',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 44:53',
#    'label': 'Ball out of play',
#    'position': '2693434',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 45:17',
#    'label': 'Throw-in',
#    'position': '2717210',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 46:40',
#    'label': 'Foul',
#    'position': '2800322',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 47:23',
#    'label': 'Yellow card',
#    'position': '2843213',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '1 - 48:30',
#    'label': 'Shots on target',
#    'position': '2910136',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 48:30',
#    'label': 'Penalty',
#    'position': '2910136',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '1 - 48:30',
#    'label': 'Goal',
#    'position': '2910629',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 00:00',
#    'label': 'Kick-off',
#    'position': '673',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 00:56',
#    'label': 'Ball out of play',
#    'position': '56720',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 01:26',
#    'label': 'Corner',
#    'position': '86558',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 01:30',
#    'label': 'Foul',
#    'position': '90745',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 01:46',
#    'label': 'Indirect free-kick',
#    'position': '106644',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 02:11',
#    'label': 'Ball out of play',
#    'position': '131800',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 02:19',
#    'label': 'Throw-in',
#    'position': '139389',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 04:16',
#    'label': 'Ball out of play',
#    'position': '256780',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 04:40',
#    'label': 'Throw-in',
#    'position': '280956',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 04:47',
#    'label': 'Ball out of play',
#    'position': '287491',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 05:16',
#    'label': 'Throw-in',
#    'position': '316526',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 05:37',
#    'label': 'Ball out of play',
#    'position': '337359',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 05:48',
#    'label': 'Throw-in',
#    'position': '348630',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 06:30',
#    'label': 'Ball out of play',
#    'position': '390390',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 07:01',
#    'label': 'Clearance',
#    'position': '421339',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 07:09',
#    'label': 'Ball out of play',
#    'position': '429996',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 07:18',
#    'label': 'Throw-in',
#    'position': '438902',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 07:42',
#    'label': 'Foul',
#    'position': '462839',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 07:50',
#    'label': 'Indirect free-kick',
#    'position': '470545',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 09:57',
#    'label': 'Shots off target',
#    'position': '597317',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 09:58',
#    'label': 'Ball out of play',
#    'position': '598756',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 10:47',
#    'label': 'Corner',
#    'position': '647507',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 10:49',
#    'label': 'Offside',
#    'position': '649281',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 11:23',
#    'label': 'Ball out of play',
#    'position': '683247',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 11:27',
#    'label': 'Throw-in',
#    'position': '687930',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 11:38',
#    'label': 'Ball out of play',
#    'position': '698600',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 11:51',
#    'label': 'Throw-in',
#    'position': '711137',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 12:38',
#    'label': 'Ball out of play',
#    'position': '758411',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 12:46',
#    'label': 'Throw-in',
#    'position': '766443',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 12:53',
#    'label': 'Shots on target',
#    'position': '773843',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 12:54',
#    'label': 'Goal',
#    'position': '774483',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 13:44',
#    'label': 'Kick-off',
#    'position': '824700',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 14:22',
#    'label': 'Ball out of play',
#    'position': '862510',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 14:27',
#    'label': 'Throw-in',
#    'position': '867807',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 14:32',
#    'label': 'Ball out of play',
#    'position': '872480',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 14:35',
#    'label': 'Throw-in',
#    'position': '875292',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 14:44',
#    'label': 'Foul',
#    'position': '884957',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 15:41',
#    'label': 'Shots on target',
#    'position': '941719',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 15:49',
#    'label': 'Offside',
#    'position': '949383',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 16:04',
#    'label': 'Indirect free-kick',
#    'position': '964685',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 17:30',
#    'label': 'Shots off target',
#    'position': '1050257',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 17:31',
#    'label': 'Ball out of play',
#    'position': '1051305',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 17:54',
#    'label': 'Clearance',
#    'position': '1074964',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 18:16',
#    'label': 'Ball out of play',
#    'position': '1096909',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 18:46',
#    'label': 'Substitution',
#    'position': '1126822',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 18:48',
#    'label': 'Substitution',
#    'position': '1128475',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 19:23',
#    'label': 'Substitution',
#    'position': '1163000',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 19:31',
#    'label': 'Throw-in',
#    'position': '1171035',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 19:34',
#    'label': 'Foul',
#    'position': '1174365',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 19:40',
#    'label': 'Indirect free-kick',
#    'position': '1180446',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 20:29',
#    'label': 'Ball out of play',
#    'position': '1229069',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 20:37',
#    'label': 'Throw-in',
#    'position': '1237119',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 20:48',
#    'label': 'Foul',
#    'position': '1248096',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 21:11',
#    'label': 'Indirect free-kick',
#    'position': '1271799',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 21:27',
#    'label': 'Ball out of play',
#    'position': '1287781',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 21:44',
#    'label': 'Throw-in',
#    'position': '1304652',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 22:33',
#    'label': 'Ball out of play',
#    'position': '1353252',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 22:43',
#    'label': 'Throw-in',
#    'position': '1363218',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 23:17',
#    'label': 'Foul',
#    'position': '1397616',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 23:34',
#    'label': 'Indirect free-kick',
#    'position': '1414038',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 23:37',
#    'label': 'Offside',
#    'position': '1417461',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 24:00',
#    'label': 'Indirect free-kick',
#    'position': '1440805',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 24:03',
#    'label': 'Foul',
#    'position': '1443918',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 24:14',
#    'label': 'Indirect free-kick',
#    'position': '1454309',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 24:50',
#    'label': 'Shots off target',
#    'position': '1490113',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 24:52',
#    'label': 'Ball out of play',
#    'position': '1492303',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 25:26',
#    'label': 'Substitution',
#    'position': '1526793',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 25:34',
#    'label': 'Clearance',
#    'position': '1534614',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 27:10',
#    'label': 'Shots on target',
#    'position': '1630133',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 27:11',
#    'label': 'Ball out of play',
#    'position': '1631959',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 27:26',
#    'label': 'Corner',
#    'position': '1646339',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 27:28',
#    'label': 'Foul',
#    'position': '1648342',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 28:20',
#    'label': 'Direct free-kick',
#    'position': '1700160',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 28:26',
#    'label': 'Shots off target',
#    'position': '1706889',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 29:06',
#    'label': 'Ball out of play',
#    'position': '1746646',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 29:18',
#    'label': 'Throw-in',
#    'position': '1758390',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 29:31',
#    'label': 'Shots on target',
#    'position': '1771546',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 30:50',
#    'label': 'Foul',
#    'position': '1850954',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 31:21',
#    'label': 'Substitution',
#    'position': '1881400',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 31:26',
#    'label': 'Indirect free-kick',
#    'position': '1886874',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 31:32',
#    'label': 'Foul',
#    'position': '1892795',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 32:09',
#    'label': 'Direct free-kick',
#    'position': '1929947',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 32:34',
#    'label': 'Shots on target',
#    'position': '1954994',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 32:36',
#    'label': 'Shots on target',
#    'position': '1956719',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 32:37',
#    'label': 'Goal',
#    'position': '1957200',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 33:27',
#    'label': 'Kick-off',
#    'position': '2007352',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 35:02',
#    'label': 'Ball out of play',
#    'position': '2102246',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 35:20',
#    'label': 'Throw-in',
#    'position': '2120766',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 36:31',
#    'label': 'Foul',
#    'position': '2191857',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 36:38',
#    'label': 'Indirect free-kick',
#    'position': '2198183',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 38:30',
#    'label': 'Shots off target',
#    'position': '2310366',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 38:31',
#    'label': 'Ball out of play',
#    'position': '2311377',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 39:04',
#    'label': 'Clearance',
#    'position': '2344064',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 39:24',
#    'label': 'Ball out of play',
#    'position': '2364100',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 39:45',
#    'label': 'Clearance',
#    'position': '2385722',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 39:56',
#    'label': 'Foul',
#    'position': '2396673',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 40:04',
#    'label': 'Indirect free-kick',
#    'position': '2404681',
#    'team': 'home',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 40:21',
#    'label': 'Ball out of play',
#    'position': '2421158',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 40:32',
#    'label': 'Throw-in',
#    'position': '2432961',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 40:54',
#    'label': 'Foul',
#    'position': '2454916',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 41:00',
#    'label': 'Indirect free-kick',
#    'position': '2460441',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 41:06',
#    'label': 'Ball out of play',
#    'position': '2466586',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 41:17',
#    'label': 'Foul',
#    'position': '2477763',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 41:35',
#    'label': 'Indirect free-kick',
#    'position': '2495543',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 41:45',
#    'label': 'Ball out of play',
#    'position': '2505827',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 41:54',
#    'label': 'Throw-in',
#    'position': '2514566',
#    'team': 'away',
#    'visibility': 'not shown'},
#   {'gameTime': '2 - 42:15',
#    'label': 'Shots off target',
#    'position': '2535082',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 42:15',
#    'label': 'Ball out of play',
#    'position': '2535604',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 42:57',
#    'label': 'Clearance',
#    'position': '2577326',
#    'team': 'home',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 43:33',
#    'label': 'Ball out of play',
#    'position': '2613290',
#    'team': 'not applicable',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 43:57',
#    'label': 'Corner',
#    'position': '2637098',
#    'team': 'away',
#    'visibility': 'visible'},
#   {'gameTime': '2 - 44:43',
#    'label': 'Ball out of play',
#    'position': '2683434',
#    'team': 'not applicable',
#    'visibility': 'visible'}],
#  'gameAwayTeam': 'Maccabi Tel Aviv',
#  'gameDate': '16/09/2015 - 21:45',
#  'gameHomeTeam': 'Chelsea',
#  'gameScore': '4 - 0'}

# %%
class VideoFrameDataset(torch.utils.data.Dataset):
    
    def __init__(self,data_dir,transform=None):
        db = "/scratch/users/mdelabrassinne/Database/SoccerDB.db"
        con = sql.connect(db)
        cur = con.cursor()
        query_result = cur.execute("SELECT Path_video FROM VIDEO WHERE Path_video LIKE '%england_epl%' OR Path_video LIKE '%france_ligue-1%' OR Path_video LIKE '%europe_uefa-champions-league%'")
        self.training_vids = copy.deepcopy([q[0] for q in query_result.fetchall()])
    
    def _extract_frames(video_path, start_time, end_time, frame_rate):
        
        frames = []
        # Open the video file
        cap = cv2.VideoCapture(video_path)

        # Set the starting frame to extract
        cap.set(cv2.CAP_PROP_POS_MSEC, start_time * 1000)

        # Calculate the total number of frames to extract
        total_frames = int((end_time - start_time) * frame_rate)

        # Extract the frames
        for i in tqdm(range(total_frames)):
            # Read the next frame
            ret, frame = cap.read()
            if ret:
                # Add the frame to the list
                frames.append(frame)
            else:
                break

            # Set the position to the next frame
            cap.set(cv2.CAP_PROP_POS_FRAMES, int(cap.get(cv2.CAP_PROP_POS_FRAMES)) + int(cap.get(cv2.CAP_PROP_FPS) / frame_rate))

        # Release the video capture
        cap.release()
        return frames
    
    def _process_gameTime(strin):
        # get from '02:44' to 164
        return int(strin[0:2])*60 + int([3:5])
        
    
    def _get_start_times(N=10):
        return np.random.choice(44*60,N)
    
    def __getitem__(self,index):    
        
        #get vid path
        vid = self.training_vids[index]
        # get a list of N start times
        start_times = self._get_start_times()
        
        #2D matrix of extracted images
        X = [_extract_frames(vid,start,start+112,1) for start in start_times]
        
        #path of the json
        json = os.path.join(os.path.dirname(videos[vid]),"Labels-v2.json")
        
        #get list of annotations
        label_list = json['annotations']
        
        #get the game half
        half = int(vid[-9])
        
        for label in label_list:
            if label['gameTime'].contains("{i} - ".format(i=half)):
                time_label = self._process_gameTime(label['gameTime'][4:])
                indices = np.where([(time_label-ti) < 112 and (time_label-ti) >0 for ti in start_times])

# %%
ex = np.random.choice(44*60,10)
ex
# Out:
# array([ 385,  916, 1469, 2261, 1902,  199, 1083, 2272,  453, 1466])

# %%
ex[np.where([(1489-ti) < 112 and (1489-ti) > 0  for ti in ex])]
# Out:
# array([1469, 1466])

# %% [markdown]
# # MODEL

# %% [markdown]
# ## 2 Layer MLP

# %%
class MLP2(nn.Module):
    def __init__(self,n_features):
        super(MLP2,self).__init__()
        self.conv1 = nn.Conv1d(n_features,MLP_FILTERS_1,MLP_KERNEL_SIZE)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv1d(MLP_FILTERS_1,MLP_FILTERS_2,MLP_KERNEL_SIZE)

    def forward(self,x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.conv2(out)
        return out

# %% [markdown]
# ## UNET ARCHITECTURE

# %%
class BottleneckResBlockContract(nn.Module):
    # Takes as input a feature matrix of size:
    #  _____
    # |     |
    # |     |
    # |     |
    # |     | T
    # |     |
    # |_____|
    #    P
    # Performs a bottleneck Resnetblock:
    # BN -> ReLU -> conv(1,P) ->BN ->ReLU -> conv(3,P) -> BN -> ReLU -> conv(1,2P) -> + -> output (of size T,2P)
    # |                                                                               ^
    # L>    ->  ->  ->  ->  ->  ->  ->  -> conv(1,2P) ->  ->  ->  ->    ->  ->  ->  ->|  
    def __init__(self,in_features):
        super(BottleneckResBlockContract,self).__init__()
        self.bn1 = nn.BatchNorm1d(in_features)
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv1d(in_features,in_features,1)
        self.bn2 = nn.BatchNorm1d(in_features)
        self.conv2 = nn.Conv1d(in_features,in_features,3,padding=PADDING_METHOD)
        self.bn3 = nn.BatchNorm1d(in_features)
        self.conv3 = nn.Conv1d(in_features,in_features*CONTRACTION_RATIO,1)
        self.conv_skip = nn.Conv1d(in_features,in_features*CONTRACTION_RATIO,1)

    def forward(self,x):
        y = self.bn1(x)
        y = self.relu(y)
        y = self.conv1(y)
        y = self.bn2(y)
        y = self.relu(y)
        y = self.conv2(y)
        y = self.bn3(y)
        y = self.relu(y)
        y = self.conv3(y)
        z = self.conv_skip(x)
        return y+z
    
class BottleneckResBlockExpand(nn.Module):
    # Takes as input a feature matrix of size:
    #  _____
    # |     |
    # |     |
    # |     |
    # |     | T
    # |     |
    # |_____|
    #    P
    # Performs a bottleneck Resnetblock:
    # BN -> ReLU -> conv(1,P/2) ->BN ->ReLU -> conv(3,P/2) -> BN -> ReLU -> conv(1,P/2) -> + -> output (of size T,P/2)
    # |                                                                               ^
    # L>    ->  ->  ->  ->  ->  ->  ->  -> conv(1,P/2) ->  ->  ->  ->    ->  ->  ->  ->|  
    def __init__(self,in_features):
        in_features = int(in_features)
        super(BottleneckResBlockExpand,self).__init__()
        self.bn1 = nn.BatchNorm1d(int(in_features))
        self.relu = nn.ReLU()
        self.conv1 = nn.Conv1d(in_features,int(in_features/CONTRACTION_RATIO),1)
        self.bn2 = nn.BatchNorm1d(int(in_features/CONTRACTION_RATIO))
        self.conv2 = nn.Conv1d(int(in_features/CONTRACTION_RATIO),int(in_features/CONTRACTION_RATIO),3,padding=PADDING_METHOD)
        self.bn3 = nn.BatchNorm1d(int(in_features/CONTRACTION_RATIO))
        self.conv3 = nn.Conv1d(int(in_features/CONTRACTION_RATIO),int(in_features/CONTRACTION_RATIO),1)
        self.conv_skip = nn.Conv1d(in_features,int(in_features/CONTRACTION_RATIO),1)

    def forward(self,x):
        y = self.bn1(x)
        y = self.relu(y)
        y = self.conv1(y)
        y = self.bn2(y)
        y = self.relu(y)
        y = self.conv2(y)
        y = self.bn3(y)
        y = self.relu(y)
        y = self.conv3(y)
        z = self.conv_skip(x)
        return y+z

class UpsamplingBlock(nn.Module):
# Takes as input a feature matrix of size (with ncol: nFeatures and nrow: nTimePoints) :
    #  _____
    # |     |
    # |     |
    # |     |
    # |     | T
    # |     |
    # |_____|
    #    P
# Upsample uses nearest neighbor to output a 2TxP matrix
# a Conv(2,P/2) is then applied with padding = same
    
    def __init__(self,in_feature):
        super(UpsamplingBlock,self).__init__()
        in_feature = int(in_feature)
        self.upsample = nn.Upsample(scale_factor=2,mode=UPSAMPLE_MODE)
        self.conv = nn.Conv1d(in_feature, int(in_feature/2),kernel_size=2, padding=PADDING_METHOD)
    
    def forward(self,x):
        out = self.upsample(x)
        out = self.conv(out)
        return out
    

class Unet1D(nn.Module):
    def __init__(self,in_feature):
        super(Unet1D,self).__init__()

        #LEFT PART
        self.maxpool = nn.MaxPool1d(2)

        self.contr1 = BottleneckResBlockContract(in_feature)
        #self.maxpool
        nb_f = in_feature*2
        self.contr2 = BottleneckResBlockContract(nb_f)
        #self.maxpool
        nb_f = nb_f*2
        self.contr3 = BottleneckResBlockContract(nb_f)
        #self.maxpool
        nb_f = nb_f*2
        self.contr4 = BottleneckResBlockContract(nb_f)
        #self.maxpool
        nb_f = nb_f*2
        ##############################################

        #DOWN PART
        
        self.contr5 = BottleneckResBlockContract(nb_f)
        nb_f = nb_f*2
        ##############################################

        #RIGHT PART

        self.upsample4 = UpsamplingBlock(nb_f)
        nb_f = nb_f/2
        #concat
        nb_f = nb_f*2
        self.expand4 = BottleneckResBlockExpand(nb_f)
        nb_f = nb_f/2

        self.upsample3 = UpsamplingBlock(nb_f)
        nb_f = nb_f/2
        #concat
        nb_f = nb_f*2
        self.expand3 = BottleneckResBlockExpand(nb_f)
        nb_f = nb_f/2

        self.upsample2 = UpsamplingBlock(nb_f)
        nb_f = nb_f/2
        #concat
        nb_f = nb_f*2
        self.expand2 = BottleneckResBlockExpand(nb_f)
        nb_f = nb_f/2

        self.upsample1 = UpsamplingBlock(nb_f)
        nb_f = nb_f/2
        #concat
        nb_f = nb_f*2
        self.expand1 = BottleneckResBlockExpand(nb_f)
        nb_f = nb_f/2

        self.upsample0 = UpsamplingBlock(nb_f)
        nb_f = nb_f/2
        #concat
        nb_f = nb_f*2
        self.expand0 = BottleneckResBlockExpand(nb_f)
        nb_f = nb_f/2

    def forward(self,x):
        # X is of shape [nbatch,64,224]

        # LEFT PART
        l0 = x #[P,T]           #Output shape
        a = self.maxpool(l0)    #[P,T/2]
        l1 = self.contr1(a)     #[P*2,T/2]
        b = self.maxpool(l1)    #[P*2,T/4]
        l2 = self.contr2(b)     #[P*4,T/4]
        c = self.maxpool(l2)    #[P*4,T/8]
        l3 = self.contr3(c)     #[P*8,T/8]
        d = self.maxpool(l3)    #[P*8,T/16]
        l4 = self.contr4(d)     #[P*16,T/16]
        e = self.maxpool(l4)    #[P*16, T/32]

        # DOWN PART
        l5 = self.contr5(e)     #[P*32,T/32]

        # RIGHT PART
        r4 = self.upsample4(l5)     #[P*16,T/16]
        t4 = torch.cat((l4,r4),1)   #[P*32,T/16]
        t4 = self.expand4(t4)       #[P*16,T/16]
        r3 = self.upsample3(t4)     #[P*8,T/8]
        t3 = torch.cat((l3,r3),1)   #[P*16,T/8]
        t3 = self.expand3(t3)       #[P*8,T/8]
        r2 = self.upsample2(t3)     #[P*4,T/4]
        t2 = torch.cat((l2,r2),1)   #[P*8,T/4]
        t2 = self.expand2(t2)       #[P*4,T/4]
        r1 = self.upsample1(t2)     #[P*2,T/2]
        t1 = torch.cat((l1,r1),1)   #[P*4,T/2]
        t1 = self.expand1(t1)       #[P*2,T/2]
        r0 = self.upsample0(t1)     #[P,T]
        t0 = torch.concat((l0,r0),1)#[P*2,T]
        t0 = self.expand0(t0)       #[P,T]

        return t0 # P features, T points

# %% [markdown]
# ## Prediction Head

# %%
class PredictionHead(nn.Sequential):
    def __init__(self,n_features):
        super(PredictionHead,self).__init__()
        self.mlp = MLP2(n_features)
        self.unet = Unet1D(MLP_FILTERS_2)
        self.convHead = nn.Conv1d(MLP_FILTERS_2,N_CLASSES,kernel_size=3,padding=PADDING_METHOD)

# %% [markdown]
# ## Temporal Head

# %%
class TemporalHead(nn.Sequential):
    def __init__(self,n_features):
        super(PredictionHead,self).__init__()
        self.mlp = MLP2(n_features)
        self.unet = Unet1D(MLP_FILTERS_2)
        self.convHead = nn.Conv1d(MLP_FILTERS_2,N_CLASSES,kernel_size=3,padding=PADDING_METHOD)

# %% [markdown]
# ## Complete models

# %%
# Model for prediction
model1 = models.resnet152(weights = models.ResNet152_Weights.IMAGENET1K_V2)
for param in model1.parameters():
    param.requires_grad = False
num_ftrs = model1.fc.in_features
model1.fc = PredictionHead(num_ftrs)
print(model1)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): PredictionHead(
#     (mlp): MLP2(
#       (conv1): Conv1d(2048, 256, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#       (conv2): Conv1d(256, 64, kernel_size=(1,), stride=(1,))
#     )
#     (unet): Unet1D(
#       (maxpool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (contr1): BottleneckResBlockContract(
#         (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       )
#       (contr2): BottleneckResBlockContract(
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(128, 256, kernel_size=(1,), stride=(1,))
#       )
#       (contr3): BottleneckResBlockContract(
#         (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(256, 512, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(256, 512, kernel_size=(1,), stride=(1,))
#       )
#       (contr4): BottleneckResBlockContract(
#         (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(512, 1024, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(512, 1024, kernel_size=(1,), stride=(1,))
#       )
#       (contr5): BottleneckResBlockContract(
#         (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(1024, 2048, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(1024, 2048, kernel_size=(1,), stride=(1,))
#       )
#       (upsample4): UpsamplingBlock(
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv): Conv1d(2048, 1024, kernel_size=(2,), stride=(1,), padding=same)
#       )
#       (expand4): BottleneckResBlockExpand(
#         (bn1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(2048, 1024, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(1024, 1024, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(2048, 1024, kernel_size=(1,), stride=(1,))
#       )
#       (upsample3): UpsamplingBlock(
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv): Conv1d(1024, 512, kernel_size=(2,), stride=(1,), padding=same)
#       )
#       (expand3): BottleneckResBlockExpand(
#         (bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(1024, 512, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(512, 512, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(1024, 512, kernel_size=(1,), stride=(1,))
#       )
#       (upsample2): UpsamplingBlock(
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv): Conv1d(512, 256, kernel_size=(2,), stride=(1,), padding=same)
#       )
#       (expand2): BottleneckResBlockExpand(
#         (bn1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(256, 256, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(512, 256, kernel_size=(1,), stride=(1,))
#       )
#       (upsample1): UpsamplingBlock(
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv): Conv1d(256, 128, kernel_size=(2,), stride=(1,), padding=same)
#       )
#       (expand1): BottleneckResBlockExpand(
#         (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(128, 128, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(256, 128, kernel_size=(1,), stride=(1,))
#       )
#       (upsample0): UpsamplingBlock(
#         (upsample): Upsample(scale_factor=2.0, mode=nearest)
#         (conv): Conv1d(128, 64, kernel_size=(2,), stride=(1,), padding=same)
#       )
#       (expand0): BottleneckResBlockExpand(
#         (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv1): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#         (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=same)
#         (bn3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (conv_skip): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (convHead): Conv1d(64, 17, kernel_size=(3,), stride=(1,), padding=same)
#   )
# )
